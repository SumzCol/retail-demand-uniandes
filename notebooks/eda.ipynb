# %%
# %load_ext kedro.ipython
# Out:
# [05/15/25 18:58:40] INFO     Using                                                                  ]8;id=625898;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\framework\project\__init__.py\__init__.py]8;;\:]8;id=827154;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\framework\project\__init__.py#270\270]8;;\
#                              'c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-
#                              packages\kedro\framework\project\rich_logging.yml' as logging
#                              configuration.
# ...

# %%
customers = catalog.load("customers")
# Out:
# [05/15/25 18:59:19] INFO     Loading data from customers (CSVDataset)...                        ]8;id=407757;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=832595;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py#401\401]8;;\

# %%
customers
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# ...

# %%
orders = catalog.load("orders")
# Out:
# [05/15/25 18:59:25] INFO     Loading data from orders (CSVDataset)...                           ]8;id=532213;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=501978;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py#401\401]8;;\

# %%
orders
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# ...

# %%
products = catalog.load("products")
# Out:
# [05/15/25 18:59:35] INFO     Loading data from products (CSVDataset)...                         ]8;id=304984;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=116764;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py#401\401]8;;\

# %%
products
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# ...

# %%
order_items = catalog.load("order_items")
order_items
# Out:
# [05/15/25 19:02:54] INFO     Loading data from order_items (CSVDataset)...                      ]8;id=39394;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=114901;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py#401\401]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# ...

# %%
order_payments = catalog.load("order_payments")
order_payments
# Out:
# [05/15/25 19:03:50] INFO     Loading data from order_payments (CSVDataset)...                   ]8;id=293499;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=527982;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py#401\401]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...

# %%
order_reviews = catalog.load("order_reviews")
order_reviews
# Out:
# [05/15/25 19:04:49] INFO     Loading data from order_reviews (CSVDataset)...                    ]8;id=447528;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=21718;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py#401\401]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...

# %%
sellers = catalog.load("sellers")
sellers
# Out:
# [05/15/25 19:05:39] INFO     Loading data from sellers (CSVDataset)...                          ]8;id=617936;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=112128;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py#401\401]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# ...

# %%
geolocation = catalog.load("geolocation")
geolocation
# Out:
# [05/15/25 19:05:57] INFO     Loading data from geolocation (CSVDataset)...                      ]8;id=303126;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=181971;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py#401\401]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...

# %%
product_category_name_translation = catalog.load("product_category_name_translation")
product_category_name_translation
# Out:
# [05/15/25 19:07:38] INFO     Loading data from product_category_name_translation                ]8;id=744215;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=82071;file://c:\Users\fdcontreras\Downloads\retail-demand-uniandes\.venv\Lib\site-packages\kedro\io\data_catalog.py#401\401]8;;\
#                              (CSVDataset)...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ...

# %%
geolocation = geolocation.rename(
    columns={"geolocation_zip_code_prefix": "zip_code_prefix"}
)

geo_unico = geolocation.drop_duplicates(
    subset=["zip_code_prefix"],
    keep="first"
)

# %%
sellers = sellers.rename(
    columns={"seller_zip_code_prefix": "zip_code_prefix"}
)

# %%
df = (
    orders
    .merge(customers,     on="customer_id",    how="left")
    .merge(order_payments, on="order_id",       how="left")
    .merge(order_reviews,  on="order_id",       how="left")
    .merge(order_items,    on="order_id",       how="left")
    .merge(products,       on="product_id",     how="left")
    .merge(sellers,        on="seller_id",      how="left")
    .merge(geo_unico,     on="zip_code_prefix",how="left")
    .merge(product_category_name_translation,      on="product_category_name", how="left")
)

# %%
print(df.shape)
df
# Out:
# (119143, 44)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 119138  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 119139  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 119140  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# ...

# %%
import pandas as pd

# 1.1 Convertir fechas a datetime
fecha_cols = [
    "order_purchase_timestamp", "order_approved_at", 
    "order_delivered_carrier_date", "order_delivered_customer_date",
    "order_estimated_delivery_date", "review_creation_date",
    "review_answer_timestamp", "shipping_limit_date"
]
for col in fecha_cols:
    df[col] = pd.to_datetime(df[col], errors="coerce")

# %%
df.info()
df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119143 entries, 0 to 119142
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       119143 non-null  object
#  1   customer_id                    119143 non-null  object
#  2   order_status                   119143 non-null  object
#  3   order_purchase_timestamp       119143 non-null  datetime64[ns]
#  4   order_approved_at              118966 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   117057 non-null  datetime64[ns]
#  6   order_delivered_customer_date  115722 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  119143 non-null  datetime64[ns]
#  8   customer_unique_id             119143 non-null  object
#  9   customer_zip_code_prefix       119143 non-null  int64
#  10  customer_city                  119143 non-null  object
# ...

# %%
import matplotlib.pyplot as plt

num_cols = df.select_dtypes(include=["int64","float64"]).columns.tolist()

# Descriptivos
print(df[num_cols].describe())

# Histogramas
for col in num_cols:
    plt.figure()
    df[col].hist(bins=30)
    plt.title(f"Distribución de {col}")
    plt.xlabel(col)
    plt.ylabel("Frecuencia")
    plt.show()
# Out:
#        customer_zip_code_prefix  payment_sequential  payment_installments  \
# count             119143.000000       119140.000000         119140.000000
# mean               35033.451298            1.094737              2.941246
# std                29823.198969            0.730141              2.777848
# min                 1003.000000            1.000000              0.000000
# 25%                11250.000000            1.000000              1.000000
# 50%                24240.000000            1.000000              2.000000
# 75%                58475.000000            1.000000              4.000000
# max                99990.000000           29.000000             24.000000
#
#        payment_value   review_score  order_item_id          price  \
# count  119140.000000  118146.000000  118310.000000  118310.000000
# mean      172.735135       4.015582       1.196543     120.646603
# std       267.776077       1.400436       0.699489     184.109691
# ...

# %%
cat_cols = df.select_dtypes(include=["object"]).columns.tolist()

# Top categorías
for col in ["order_status","payment_type","customer_state","seller_state","product_category_name_english"]:
    top = df[col].value_counts().head(10)
    print(f"\n{col}:\n", top)
    plt.figure()
    top.plot.bar()
    plt.title(f"Top 10 de {col}")
    plt.show()
# Out:
# order_status:
#  order_status
# delivered      115723
# shipped          1256
# canceled          750
# unavailable       652
# invoiced          378
# processing        376
# created             5
# approved            3
# Name: count, dtype: int64
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# payment_type:
#  payment_type
# credit_card    87776
# boleto         23190
# voucher         6465
# debit_card      1706
# not_defined        3
# Name: count, dtype: int64
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# customer_state:
#  customer_state
# SP    50265
# RJ    15518
# MG    13819
# RS     6573
# PR     6043
# SC     4345
# BA     4091
# DF     2516
# GO     2466
# ES     2360
# Name: count, dtype: int64
# ...

# %%
# 3.1 Pedidos por mes
series = df.set_index("order_purchase_timestamp")["order_id"]
pedidos_mes = series.resample("M").nunique()

plt.figure()
pedidos_mes.plot()
plt.title("Pedidos únicos por mes")
plt.ylabel("Nº de pedidos")
plt.show()

# 3.2 Tiempos de entrega
df["delivery_time_days"] = (
    df["order_delivered_customer_date"] - df["order_purchase_timestamp"]
).dt.days

plt.figure()
df["delivery_time_days"].hist(bins=30)
plt.title("Días entre compra y entrega")
plt.xlabel("Días")
plt.ylabel("Frecuencia")
plt.show()
# Out:
# [05/15/25 20:31:24] WARNING  C:\Users\fdcontreras\AppData\Local\Temp\ipykernel_52120\4096751181.py: ]8;id=886912;file://C:\Users\fdcontreras\AppData\Local\Programs\Python\Python313\Lib\warnings.py\warnings.py]8;;\:]8;id=377890;file://C:\Users\fdcontreras\AppData\Local\Programs\Python\Python313\Lib\warnings.py#110\110]8;;\
#                              3: FutureWarning: 'M' is deprecated and will be removed in a future
#                              version, please use 'ME' instead.
#                                pedidos_mes = series.resample("M").nunique()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>

# %%
# 4.1 Relación precio vs. freight_value
plt.figure()
plt.scatter(df["price"], df["freight_value"], alpha=0.3)
plt.title("Precio vs. Valor de envío")
plt.xlabel("Price")
plt.ylabel("Freight Value")
plt.show()

# 4.2 Boxplots por categoría de producto
for col in ["product_category_name_english"]:
    # Selecciona top 5 categorías
    top5 = df[col].value_counts().head(5).index
    subset = df[df[col].isin(top5)]
    plt.figure()
    subset.boxplot(column="price", by=col, rot=45)
    plt.title("Precio por categoría (Top 5)")
    plt.suptitle("")
    plt.ylabel("Price")
    plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 0 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>

# %%
# 5.1 Distribución de puntuaciones
plt.figure()
df["review_score"].value_counts().sort_index().plot.bar()
plt.title("Distribución de review_score")
plt.xlabel("Score")
plt.ylabel("Frecuencia")
plt.show()

# 5.2 Longitud de comentario
df["msg_len"] = df["review_comment_message"].fillna("").str.len()
plt.figure()
df["msg_len"].hist(bins=30)
plt.title("Longitud de mensajes de review")
plt.xlabel("Caracteres")
plt.ylabel("Frecuencia")
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>

# %%
# 6.1 Ventas por estado de cliente
ventas_estado = df.groupby("customer_state")["order_id"].nunique().sort_values(ascending=False)
plt.figure()
ventas_estado.head(10).plot.bar()
plt.title("Pedidos únicos por estado (clientes)")
plt.ylabel("Nº pedidos")
plt.show()

# 6.2 Mapa de calor de lat/lng (opcional, requiere geopandas o folium)
# Aquí podrías usar folium para un scatter map de geolocation_lat/lng.
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>

# %%
df["order_purchase_timestamp"]        = pd.to_datetime(df["order_purchase_timestamp"])
df["order_delivered_customer_date"]   = pd.to_datetime(df["order_delivered_customer_date"])

df["delivery_time_days"] = (
    df["order_delivered_customer_date"] 
    - df["order_purchase_timestamp"]
).dt.days

print("Columns:", list(df.columns))
print(df["delivery_time_days"].head())
# Out:
# Columns: ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date', 'customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value', 'review_id', 'review_score', 'review_comment_title', 'review_comment_message', 'review_creation_date', 'review_answer_timestamp', 'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date', 'price', 'freight_value', 'product_category_name', 'product_name_lenght', 'product_description_lenght', 'product_photos_qty', 'product_weight_g', 'product_length_cm', 'product_height_cm', 'product_width_cm', 'zip_code_prefix', 'seller_city', 'seller_state', 'geolocation_lat', 'geolocation_lng', 'geolocation_city', 'geolocation_state', 'product_category_name_english', 'delivery_time_days', 'msg_len']
# 0     8.0
# 1     8.0
# ...

# %%
num_cols = df.select_dtypes(include=["int64","float64"]).columns.tolist()
corr = df[num_cols].corr()
print(corr["delivery_time_days"].sort_values(ascending=False))
plt.figure(figsize=(10, 8))
plt.matshow(corr, cmap="coolwarm", fignum=1)
# Out:
# delivery_time_days            1.000000
# customer_zip_code_prefix      0.271288
# freight_value                 0.212870
# msg_len                       0.093766
# product_weight_g              0.084176
# product_height_cm             0.068197
# product_length_cm             0.066424
# price                         0.061389
# payment_value                 0.060449
# geolocation_lat               0.051970
# zip_code_prefix               0.046567
# payment_installments          0.043061
# product_width_cm              0.038374
# product_description_lenght    0.006117
# payment_sequential            0.001822
# product_name_lenght          -0.003111
# order_item_id                -0.016534
# product_photos_qty           -0.026910
# geolocation_lng              -0.042072
# review_score                 -0.302750
# Name: delivery_time_days, dtype: float64
# ...
